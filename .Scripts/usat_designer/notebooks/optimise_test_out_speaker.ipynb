# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, project_root)

from usat_designer.processing.launch_usat import start_decoding
import xml.etree.ElementTree as ET
import pickle

# %%
test_params = "../test_xml_files/5OAto704.xml"
tree        = ET.parse(test_params)
root        = tree.getroot()
xml_string  = ET.tostring(root, encoding='unicode')

optimisation_data = start_decoding(xml_string)

with open("saved_vars.pkl", "wb") as f:
    pickle.dump(optimisation_data, f)

# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, project_root)

from usat_designer.processing.launch_usat import start_decoding
import xml.etree.ElementTree as ET
import pickle

# %%
with open("saved_vars.pkl", "rb") as f:
    optimisation_data = pickle.load(f)

# %%
from usat_designer.processing.constants import *
from usat_designer.processing.launch_usat import generate_base64_plots
from usat_designer.processing.plots_usat_designer import *


plot_data = generate_base64_plots(optimisation_data, False)

# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, project_root)

from usat_designer.processing.launch_usat import start_decoding
import xml.etree.ElementTree as ET

# %%
test_params = "/Users/james/Documents/Development/USAT-Designer/.Scripts/usat_designer/test_xml_files/502to301irr.xml"
tree        = ET.parse(test_params)
root        = tree.getroot()
xml_string  = ET.tostring(root, encoding='unicode')

optimisation_data = start_decoding(xml_string)
# Out:
# Cost value for initial transcoding matrix:  382.5684
# Optimization time  1.0007119178771973
# Generating plots in subprocess...
# Generating plots in thread...
# Returning base 64
# Creating Energy Plot
# Creating standard figure...
# Creating base map...
# Creating scatter
# Assigning colour bar and title
# Creating standard figure...
# Creating base map...
# Creating scatter
# Assigning colour bar and title
# Creating standard figure...
# Creating base map...
# Creating scatter
# Assigning colour bar and title
# Creating standard figure...
# Creating base map...
# Creating scatter
# Assigning colour bar and title
# Creating standard figure...
# Creating base map...
# Creating scatter
# Assigning colour bar and title
# ...
# Returning tuple...
